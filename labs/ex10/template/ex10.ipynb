# %%
# Useful starting lines
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load data

# %%
from helper import load_data, normalize_data

data = load_data()
(N, d) = data.shape
print("Number of data points: ", N)
print("Dimension of each data point: ", d)
# Out:
# Number of data points:  272
# Dimension of each data point:  2

# %% [markdown]
# ### Initialize your cluster centers

# %%
def initialize_clusters(data, k):
    """randomly initialize the k cluster centers (the means). Make sure you choose k clusters from the data itself.

    Args:
        data: shape = (N, d). original data.
        k: integer number. predefined number of clusters for the k-means algorithm.

        k: integer number. predefined number of clusters for the k-means algorithm.
    Returns:
        numpy array with shape (k, d) which corresponds to the k initial clusters.
    """
    ####################################
    ### ___ Enter your code here ___ ###
    N,_ = data.shape
    initial_clusters = data[np.random.choice(N,k,replace=False)]
    return initial_clusters
    ####################################

# %% [markdown]
# ### Update k-means parameters

# %% [markdown]
# #### Build distance matrix
# Build a distance matrix, collecting the distances of the original dataset to the means of the clusters.
#
# NOTE: once you finish your `build_distance_matrix`, please copy the function to the `helper.py` function. Otherwise, the `kmeans` function will not work.

# %% [markdown]
# #### Update k-means parameters

# %%
def update_kmeans_parameters(data, mu_old):
    """compute one step of the kmeans algorithm: using mu_old, find to which cluster each datapoint belongs to,
            then update the parameter cluster centers.

    Args:
        data:   numpy array of shape = (N, d). original data.
        mu_old: numpy array of shape = (k, d). Each row corresponds to a cluster center.
    Returns:
        losses: shape (N, ), contains the (old) squared distances of each data point to its (old) cluster mean (computed from mu_old).
        assignments: vector of shape (N, ) which contains the cluster associated to each data point.
        mu: updated vector mu of shape (k, d) where each row corresponds to the new cluster center.
    """
    ####################################
    ### ___ Enter your code here ___ ###
    N,_ = data.shape
    k,_ = mu_old.shape
    losses = np.zeros(N)
    assignments = np.zeros(N)
    mu = np.zeros((k,d))
    for i in range(N):
        distances = np.zeros(k)
        for j in range(k):
            distances[j] = np.linalg.norm(data[i] - mu_old[j])
        losses[i] = np.min(distances)
        assignments[i] = np.argmin(distances)
    for j in range(k):
        mu[j] = np.mean(data[assignments==j],axis=0)
    return losses, assignments, mu
    ####################################

# %% [markdown]
# #### Play with k-means

# %%
from helper import build_dir
from plots import plot


def kmeans(data, k, max_iters, threshold, verbose=True):
    """run the k-means algorithm."""
    output_figure = "kmeans_figures/"
    # initialize the cluster.
    mu_old = initialize_clusters(data, k)
    # init some empty lists to store the result.
    loss_list = []

    # start the kmeans algorithm.
    for iteration in range(max_iters):
        # update z and mu
        losses, assignments, mu = update_kmeans_parameters(data, mu_old)
        # calculate the average loss over all points
        average_loss = np.mean(losses)
        loss_list.append(average_loss)
        if verbose:
            print(
                "The current iteration of k-means is: {i}, \
                   the average loss is {l}.".format(
                    i=iteration, l=average_loss
                )
            )
        # check convergence
        if iteration > 0 and np.abs(loss_list[-1] - loss_list[-2]) < threshold:
            break
        # output plot
        if verbose:
            plot(data, mu, mu_old, output_figure + "kmean_iter{i}".format(i=iteration))
        # update k-means information.
        mu_old = mu
    return average_loss


# define parameters
k = 2
max_iters = 10
threshold = 1e-5
output_figure = "kmeans_figures/"

# build figure dir
build_dir(output_figure)

# run kmeans algorithm
average_loss = kmeans(data, k, max_iters, threshold)
# Out:
# The current iteration of k-means is: 0,                    the average loss is 10.965947890660834.
# The current iteration of k-means is: 1,                    the average loss is 8.349014600760317.
# The current iteration of k-means is: 2,                    the average loss is 5.9008627615299565.
# The current iteration of k-means is: 3,                    the average loss is 4.825244167521961.
# The current iteration of k-means is: 4,                    the average loss is 4.686722544208671.
# The current iteration of k-means is: 5,                    the average loss is 4.68244411160236.
# The current iteration of k-means is: 6,                    the average loss is 4.68244411160236.

# %% [markdown]
# ### Plotting the loss as a function of number of clusters

# %%
# don't worry about empty slice warnings
import warnings

warnings.filterwarnings("ignore")

losses = []
ks = np.arange(2, 17)
for k in ks:
    average_loss = kmeans(data, k, max_iters, threshold, verbose=False)
    losses += [average_loss]
plt.figure(figsize=(5, 3))
plt.xlabel("number of clusters k", fontsize=13)
plt.ylabel("average loss", fontsize=13)
plt.plot(ks, losses)
plt.show()

# %% [markdown]
# ## Using k-means for image compresson

# %% [markdown]
# #### load image

# %%
from helper import load_image

image_path = "mandrill.png"
original_image = load_image(image_path)
print(
    "Original image: the shape of image={s}, the data type={dt}.".format(
        s=original_image.shape, dt=original_image.dtype
    )
)
# Out:
# Original image: the shape of image=(480, 480, 3), the data type=float32.

# %% [markdown]
# #### preprocess image

# %%
def preprocess_image(original_image):
    """preprocess the image.
    vectorize the three matrices (each matrix corresponds to a RGB color channel). **don't normalize!**

    Args:
        original_image: numpy array of shape (480, 480, 3)
    Returns:
        processed_image: numpy array of shape (480*480, 3)
    """
    ####################################
    ### ___ Enter your code here ___ ###
    ####################################


processed_image = preprocess_image(original_image)

# %%
from plots import plot_image_compression


def kmean_compression(original_image, processed_image, k, max_iters, threshold):
    """using k-means for image compression.
    Args:
        original_image: numpy array of shape (480, 480, 3).
        processed_image: numpy array of shape (480*480, 3).
        k: scalar. Number of clusters.
        max_iters: integer. Max number of iterations for the kmeans algorithm.
        threshold: scalar. Stop the kmeans algorithm if the loss decrease between two iterations
                        is lower than the threshold.
    """

    ####################################
    ### ___ Enter your code here ___ ###
    ####################################
    # plot histogram
    plot_image_compression(original_image, processed_image, assignments, mu, k)


# define parameters
k = 5
max_iter = 100
threshold = 1e-7

# use kmeans to compress image
kmean_compression(original_image, processed_image, k, max_iter, threshold)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/vincentroduit/Library/CloudStorage/GoogleDrive-roduit.v@gmail.com/My Drive/ML_course/labs/ex10/template/ex10.ipynb Cell 21 line 2
#      <a href='vscode-notebook-cell:/Users/vincentroduit/Library/CloudStorage/GoogleDrive-roduit.v%40gmail.com/My%20Drive/ML_course/labs/ex10/template/ex10.ipynb#X25sZmlsZQ%3D%3D?line=24'>25</a> threshold = 1e-7
#      <a href='vscode-notebook-cell:/Users/vincentroduit/Library/CloudStorage/GoogleDrive-roduit.v%40gmail.com/My%20Drive/ML_course/labs/ex10/template/ex10.ipynb#X25sZmlsZQ%3D%3D?line=26'>27</a> # use kmeans to compress image
# ---> <a href='vscode-notebook-cell:/Users/vincentroduit/Library/CloudStorage/GoogleDrive-roduit.v%40gmail.com/My%20Drive/ML_course/labs/ex10/template/ex10.ipynb#X25sZmlsZQ%3D%3D?line=27'>28</a> kmean_compression(original_image, processed_image, k, max_iter, threshold)
#
# /Users/vincentroduit/Library/CloudStorage/GoogleDrive-roduit.v@gmail.com/My Drive/ML_course/labs/ex10/template/ex10.ipynb Cell 21 line 1
#       <a href='vscode-notebook-cell:/Users/vincentroduit/Library/CloudStorage/GoogleDrive-roduit.v%40gmail.com/My%20Drive/ML_course/labs/ex10/template/ex10.ipynb#X25sZmlsZQ%3D%3D?line=4'>5</a> """using k-means for image compression.
#       <a href='vscode-notebook-cell:/Users/vincentroduit/Library/CloudStorage/GoogleDrive-roduit.v%40gmail.com/My%20Drive/ML_course/labs/ex10/template/ex10.ipynb#X25sZmlsZQ%3D%3D?line=5'>6</a> Args:
#       <a href='vscode-notebook-cell:/Users/vincentroduit/Library/CloudStorage/GoogleDrive-roduit.v%40gmail.com/My%20Drive/ML_course/labs/ex10/template/ex10.ipynb#X25sZmlsZQ%3D%3D?line=6'>7</a>     original_image: numpy array of shape (480, 480, 3).
#    (...)
#      <a href='vscode-notebook-cell:/Users/vincentroduit/Library/CloudStorage/GoogleDrive-roduit.v%40gmail.com/My%20Drive/ML_course/labs/ex10/template/ex10.ipynb#X25sZmlsZQ%3D%3D?line=11'>12</a>                     is lower than the threshold.
#      <a href='vscode-notebook-cell:/Users/vincentroduit/Library/CloudStorage/GoogleDrive-roduit.v%40gmail.com/My%20Drive/ML_course/labs/ex10/template/ex10.ipynb#X25sZmlsZQ%3D%3D?line=12'>13</a> """
#      <a href='vscode-notebook-cell:/Users/vincentroduit/Library/CloudStorage/GoogleDrive-roduit.v%40gmail.com/My%20Drive/ML_course/labs/ex10/template/ex10.ipynb#X25sZmlsZQ%3D%3D?line=14'>15</a> ####################################
#      <a href='vscode-notebook-cell:/Users/vincentroduit/Library/CloudStorage/GoogleDrive-roduit.v%40gmail.com/My%20Drive/ML_course/labs/ex10/template/ex10.ipynb#X25sZmlsZQ%3D%3D?line=15'>16</a> ### ___ Enter your code here ___ ###
#      <a href='vscode-notebook-cell:/Users/vincentroduit/Library/CloudStorage/GoogleDrive-roduit.v%40gmail.com/My%20Drive/ML_course/labs/ex10/template/ex10.ipynb#X25sZmlsZQ%3D%3D?line=16'>17</a> ####################################
#      <a href='vscode-notebook-cell:/Users/vincentroduit/Library/CloudStorage/GoogleDrive-roduit.v%40gmail.com/My%20Drive/ML_course/labs/ex10/template/ex10.ipynb#X25sZmlsZQ%3D%3D?line=17'>18</a> # plot histogram
# ---> <a href='vscode-notebook-cell:/Users/vincentroduit/Library/CloudStorage/GoogleDrive-roduit.v%40gmail.com/My%20Drive/ML_course/labs/ex10/template/ex10.ipynb#X25sZmlsZQ%3D%3D?line=18'>19</a> plot_image_compression(original_image, processed_image, assignments, mu, k)
#
# NameError: name 'assignments' is not defined
